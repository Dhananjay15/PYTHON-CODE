# %%
import pandas as pd
import pandas_datareader as pdr
from datetime import datetime

# %%
df_tesla = pdr.get_data_yahoo('TSLA')

# %%
df_tesla
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-07-07   63.400002   61.476002   62.700001   62.644001  70884500.0
# 2017-07-10   63.588001   60.625999   62.580002   63.209999  69104500.0
# 2017-07-11   65.456001   62.860001   63.200001   65.444000  57797000.0
# 2017-07-12   66.620003   64.900002   66.080002   65.903999  51730500.0
# 2017-07-13   66.320000   63.993999   66.022003   64.681999  42972500.0
# ...                ...         ...         ...         ...         ...
# 2022-06-29  693.520020  666.820007  691.500000  685.469971  27632400.0
# 2022-06-30  688.369995  656.590027  673.530029  673.419983  31533500.0
# 2022-07-01  690.690002  666.359985  681.000000  681.789978  24781500.0
# 2022-07-05  699.440002  648.500000  669.000000  699.200012  28193700.0
# 2022-07-06  703.690002  681.559998  692.340027  695.200012  23892300.0
#
#              Adj Close
# Date
# 2017-07-07   62.644001
# 2017-07-10   63.209999
# 2017-07-11   65.444000
# ...

# %%
df_tesla['High'].plot(xlim=['2020-1-1','2022-1-1'],ls='--',figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
index = df_tesla.loc['2020-1-1':'2022-1-1'].index
volume = df_tesla.loc['2020-1-1':'2022-1-1']['Volume']
Open =  df_tesla.loc['2020-1-1':'2022-1-1']['Open']
close = df_tesla.loc['2020-1-1':'2022-1-1']['Close']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig,axis = plt.subplots(figsize=(12,4))
axis.plot(index,Open)

# %%
df_tesla.Open.plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla = df_tesla.reset_index()
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   datetime64[ns]
#  1   High       1258 non-null   float64
#  2   Low        1258 non-null   float64
#  3   Open       1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Volume     1258 non-null   float64
#  6   Adj Close  1258 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 68.9 KB

# %%
df_tesla
# Out:
#            Date        High         Low        Open       Close      Volume  \
# 0    2017-07-07   63.400002   61.476002   62.700001   62.644001  70884500.0
# 1    2017-07-10   63.588001   60.625999   62.580002   63.209999  69104500.0
# 2    2017-07-11   65.456001   62.860001   63.200001   65.444000  57797000.0
# 3    2017-07-12   66.620003   64.900002   66.080002   65.903999  51730500.0
# 4    2017-07-13   66.320000   63.993999   66.022003   64.681999  42972500.0
# ...         ...         ...         ...         ...         ...         ...
# 1253 2022-06-29  693.520020  666.820007  691.500000  685.469971  27632400.0
# 1254 2022-06-30  688.369995  656.590027  673.530029  673.419983  31533500.0
# 1255 2022-07-01  690.690002  666.359985  681.000000  681.789978  24781500.0
# 1256 2022-07-05  699.440002  648.500000  669.000000  699.200012  28193700.0
# 1257 2022-07-06  703.690002  681.559998  692.340027  695.200012  23892300.0
#
#        Adj Close
# 0      62.644001
# 1      63.209999
# ...

# %%
df_tesla = df_tesla.set_index('Date',drop=True)
df_tesla
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-07-07   63.400002   61.476002   62.700001   62.644001  70884500.0
# 2017-07-10   63.588001   60.625999   62.580002   63.209999  69104500.0
# 2017-07-11   65.456001   62.860001   63.200001   65.444000  57797000.0
# 2017-07-12   66.620003   64.900002   66.080002   65.903999  51730500.0
# 2017-07-13   66.320000   63.993999   66.022003   64.681999  42972500.0
# ...                ...         ...         ...         ...         ...
# 2022-06-29  693.520020  666.820007  691.500000  685.469971  27632400.0
# 2022-06-30  688.369995  656.590027  673.530029  673.419983  31533500.0
# 2022-07-01  690.690002  666.359985  681.000000  681.789978  24781500.0
# 2022-07-05  699.440002  648.500000  669.000000  699.200012  28193700.0
# 2022-07-06  703.690002  681.559998  692.340027  695.200012  23892300.0
#
#              Adj Close
# Date
# 2017-07-07   62.644001
# 2017-07-10   63.209999
# 2017-07-11   65.444000
# ...

# %%
#TIME RESAMPLING
df_tesla.resample(rule='A').min()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-12-31   60.891998   58.526001   59.900002   59.852001  15247500.0
# 2018-12-31   52.066002   48.917999   50.556000   50.112000  15403500.0
# 2019-12-31   37.335999   35.397999   36.220001   35.793999  12328000.0
# 2020-12-31   80.972000   70.101997   74.940002   72.244003  17357700.0
# 2021-12-31  566.210022  539.489990  552.549988  563.000000   9800600.0
# 2022-12-31  653.919983  620.570007  623.849976  628.159973  16330900.0
#
#              Adj Close
# Date
# 2017-12-31   59.852001
# 2018-12-31   50.112000
# 2019-12-31   35.793999
# 2020-12-31   72.244003
# 2021-12-31  563.000000
# 2022-12-31  628.159973

# %%
df_tesla.resample(rule='A').max()
# Out:
#                    High          Low         Open        Close       Volume  \
# Date
# 2017-12-31    77.921997    75.536003    76.050003    77.000000   98957000.0
# 2018-12-31    77.491997    73.424004    75.000000    75.914001  168248500.0
# 2019-12-31    87.061996    85.269997    87.000000    86.188004  150030500.0
# 2020-12-31   718.719971   691.119995   699.989990   705.669983  304694000.0
# 2021-12-31  1243.489990  1217.000000  1234.410034  1229.910034   89396500.0
# 2022-12-31  1208.000000  1136.040039  1189.550049  1199.780029   50521900.0
#
#               Adj Close
# Date
# 2017-12-31    77.000000
# 2018-12-31    75.914001
# 2019-12-31    86.188004
# 2020-12-31   705.669983
# 2021-12-31  1229.910034
# 2022-12-31  1199.780029

# %%
m_df = pdr.get_data_yahoo('MSFT')
m_df
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-07-07   69.839996   68.699997   68.699997   69.459999  16878300.0
# 2017-07-10   70.250000   69.199997   69.459999   69.980003  15014500.0
# 2017-07-11   70.680000   69.750000   70.000000   69.989998  17460000.0
# 2017-07-12   71.279999   70.550003   70.690002   71.150002  17750900.0
# 2017-07-13   72.040001   71.309998   71.500000   71.769997  20269800.0
# ...                ...         ...         ...         ...         ...
# 2022-06-30  259.529999  252.899994  257.049988  256.829987  31730900.0
# 2022-07-01  259.769989  254.610001  256.390015  259.579987  22825200.0
# 2022-07-05  262.980011  254.740005  256.160004  262.850006  22941000.0
# 2022-07-06  267.989990  262.399994  263.750000  266.209991  23810300.0
# 2022-07-07  265.834991  265.019989  263.750000  265.717987    515819.0
#
#              Adj Close
# Date
# 2017-07-07   65.059975
# 2017-07-10   65.547035
# 2017-07-11   65.556404
# ...

# %%
m_df.resample(rule='A').max()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2017-12-31   87.500000   86.230003   87.120003   86.849998   71066700.0
# 2018-12-31  116.180000  114.930000  115.419998  115.610001  111242100.0
# 2019-12-31  159.550003  158.220001  159.449997  158.960007   55636400.0
# 2020-12-31  232.860001  227.350006  229.270004  231.649994   97012700.0
# 2021-12-31  349.670013  342.200012  344.619995  343.109985   69870600.0
# 2022-12-31  338.000000  329.779999  335.350006  334.750000   90428900.0
#
#              Adj Close
# Date
# 2017-12-31   82.192528
# 2018-12-31  110.825478
# 2019-12-31  155.302612
# 2020-12-31  228.120422
# 2021-12-31  341.606384
# 2022-12-31  333.283020

# %%
m_df[m_df['Close'] == m_df.Close.max()]
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-11-19  345.100006  342.200012  342.640015  343.109985  21963400.0
#
#              Adj Close
# Date
# 2021-11-19  341.606384

# %%
m_df[m_df['Close'] == m_df.Close.min()]
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-07-07  69.839996  68.699997  68.699997  69.459999  16878300.0  65.059975

# %%
df_tesla['Open:30 days rolling']=df_tesla['Open'].rolling(30).mean()

# %%
df_tesla[['Open','Open:30 days rolling']].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#simple moving average
#equal importance
df_tesla['Open'].plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['10 days OPEN moving average'] = df_tesla['Open'].rolling(window=10,min_periods=1).mean()

# %%
df_tesla[['Open','10 days OPEN moving average']].plot(xlim=['2020-1-1','2022-1-1'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#cummalative moving average
#expanding
df_tesla['Open'].expanding().mean().plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#EMWA prevents lags -- exponential moving average
df_tesla['ema_0.1'] = df_tesla['Open'].ewm(alpha=0.1, adjust=False).mean()

# %%
df_tesla[['Open','ema_0.1']].plot(xlim=['2020-1-1','2022-1-1'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['ema_0.1'] = df_tesla['Open'].ewm(alpha=0.1, adjust=False).mean()

# %%
df_tesla[['Open','ema_0.1','ema_0.3']].plot(xlim=['2020-1-1','2022-1-1'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['ema_5days'] = df_tesla['Open'].ewm(span=5).mean()

# %%
df_tesla[['Open','ema_0.3','ema_5days']].plot(xlim=['2020-1-1','2022-1-1'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sms
import pandas as pd

# %matplotlib inline

# %%
df_airline=pd.read_csv('airline.csv')
df_airline.head()
# Out:
#      Month  Thousands of Passengers
# 0  1949-01                      112
# 1  1949-02                      118
# 2  1949-03                      132
# 3  1949-04                      129
# 4  1949-05                      121

# %%
df_airline.isnull().sum()
# Out:
# Month                      0
# Thousands of Passengers    0
# dtype: int64

# %%
df_airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Month                    144 non-null    object
#  1   Thousands of Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
df_airline['Month']=pd.to_datetime(df_airline['Month'])

# %%
df_airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Month                    144 non-null    datetime64[ns]
#  1   Thousands of Passengers  144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %%
df_airline.set_index('Month',inplace=True)

# %%
df_airline.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %%
df_airline.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def adf_test(series):
    result=adfuller(series)
    print('ADF Statistics: {}'.format(result[0]))
    print('p- value: {}'.format(result[1]))
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adf_test(df_airline['Thousands of Passengers'])
# Out:
# ADF Statistics: 0.8153688792060482
# p- value: 0.991880243437641
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
'''
PACF for seasonal data // pacf ---> AR --> P
ACF for stationary // ACF --> moving average -->q
d is differencing ,,remove seasonality
'''

# %%
## Use Techniques Differencing
df_airline['Passengers First Difference']=df_airline['Thousands of Passengers']-df_airline['Thousands of Passengers'].shift(1)

# %%
df_airline.head()
# Out:
#             Thousands of Passengers  Passengers First Difference
# Month
# 1949-01-01                      112                          NaN
# 1949-02-01                      118                          6.0
# 1949-03-01                      132                         14.0
# 1949-04-01                      129                         -3.0
# 1949-05-01                      121                         -8.0

# %%
## Use Techniques Differencing
df_airline['Passengers Second Difference']=df_airline['Passengers First Difference']-df_airline['Passengers First Difference'].shift(1)

# %%
adf_test(df_airline['Passengers Second Difference'].dropna())
# Out:
# ADF Statistics: -16.384231542468505
# p- value: 2.7328918500142407e-29
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
### 12 months 
## Use Techniques Differencing
df_airline['Passengers 12 Difference']=df_airline['Thousands of Passengers']-df_airline['Thousands of Passengers'].shift(12)

# %%
adf_test(df_airline['Passengers 12 Difference'].dropna())
# Out:
# ADF Statistics: -3.383020726492481
# p- value: 0.011551493085514952
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
acf = plot_acf(df_airline["Passengers Second Difference"].dropna())

# %%
acf12 = plot_acf(df_airline["Passengers 12 Difference"].dropna())
pacf12 = plot_pacf(df_airline["Passengers 12 Difference"].dropna())
# Out:
# C:\Users\dhana\anaconda3\envs\projects\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
### split train and test data
df_airline
# Out:
#             Thousands of Passengers  Passengers First Difference  \
# Month
# 1949-01-01                      112                          NaN
# 1949-02-01                      118                          6.0
# 1949-03-01                      132                         14.0
# 1949-04-01                      129                         -3.0
# 1949-05-01                      121                         -8.0
# ...                             ...                          ...
# 1960-08-01                      606                        -16.0
# 1960-09-01                      508                        -98.0
# 1960-10-01                      461                        -47.0
# 1960-11-01                      390                        -71.0
# 1960-12-01                      432                         42.0
#
#             Passengers Second Difference  Passengers 12 Difference
# Month
# 1949-01-01                           NaN                       NaN
# ...

# %%
from datetime import datetime,timedelta
train_dataset_end=datetime(1955,12,1)
test_dataset_end=datetime(1960,12,1)

# %%
train_data=df_airline[:train_dataset_end]
test_data=df_airline[train_dataset_end+timedelta(days=1):test_dataset_end]

# %%
##prediction
pred_start_date=test_data.index[0]
pred_end_date=test_data.index[-1]

# %%
test_data
# Out:
#             Thousands of Passengers  Passengers First Difference  \
# Month
# 1956-01-01                      284                          6.0
# 1956-02-01                      277                         -7.0
# 1956-03-01                      317                         40.0
# 1956-04-01                      313                         -4.0
# 1956-05-01                      318                          5.0
# 1956-06-01                      374                         56.0
# 1956-07-01                      413                         39.0
# 1956-08-01                      405                         -8.0
# 1956-09-01                      355                        -50.0
# 1956-10-01                      306                        -49.0
# 1956-11-01                      271                        -35.0
# 1956-12-01                      306                         35.0
# 1957-01-01                      315                          9.0
# ...

# %%
train_data
# Out:
#             Thousands of Passengers  Passengers First Difference  \
# Month
# 1949-01-01                      112                          NaN
# 1949-02-01                      118                          6.0
# 1949-03-01                      132                         14.0
# 1949-04-01                      129                         -3.0
# 1949-05-01                      121                         -8.0
# ...                             ...                          ...
# 1955-08-01                      347                        -17.0
# 1955-09-01                      312                        -35.0
# 1955-10-01                      274                        -38.0
# 1955-11-01                      237                        -37.0
# 1955-12-01                      278                         41.0
#
#             Passengers Second Difference  Passengers 12 Difference
# Month
# 1949-01-01                           NaN                       NaN
# ...

# %%
## create a ARIMA model
from statsmodels.tsa.arima.model import ARIMA

# %%
model_ARIMA=ARIMA(train_data['Thousands of Passengers'],order=(21,2,5))
# Out:
# C:\Users\dhana\anaconda3\envs\projects\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\dhana\anaconda3\envs\projects\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\dhana\anaconda3\envs\projects\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model_Arima_fit=model_ARIMA.fit()
# Out:
# C:\Users\dhana\anaconda3\envs\projects\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\dhana\anaconda3\envs\projects\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\dhana\anaconda3\envs\projects\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model_Arima_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   SARIMAX Results
# ...
# Dep. Variable:     Thousands of Passengers   No. Observations:                   84
# Model:                     ARIMA(21, 2, 5)   Log Likelihood                -303.253
# Date:                     Sat, 16 Jul 2022   AIC                            660.505
# Time:                             19:59:47   BIC                            725.487
# Sample:                         01-01-1949   HQIC                           686.594
#                               - 12-01-1955
# Covariance Type:                       opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4111      2.661     -0.154      0.877      -5.627       4.805
# ar.L2          0.0131      1.481      0.009      0.993      -2.890       2.917
# ...

# %%
##prediction
pred_start_date=test_data.index[0]
pred_end_date=test_data.index[-1]
print(pred_start_date)
print(pred_end_date)
# Out:
# 1956-01-01 00:00:00
# 1960-12-01 00:00:00

# %%
pred=model_Arima_fit.predict(start=pred_start_date,end=pred_end_date)
residuals=test_data['Thousands of Passengers']-pred

# %%
model_Arima_fit.resid.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
test_data['Predicted_ARIMA']=pred
# Out:
# C:\Users\dhana\AppData\Local\Temp\ipykernel_15840\95659616.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['Predicted_ARIMA']=pred

# %%
test_data[['Thousands of Passengers','Predicted_ARIMA']].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
acf12 = plot_acf(df_airline["Passengers 12 Difference"].dropna())
pacf12 = plot_pacf(df_airline["Passengers 12 Difference"].dropna())
# Out:
# C:\Users\dhana\anaconda3\envs\projects\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
## create a SARIMA model
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model_SARIMA=SARIMAX(train_data['Thousands of Passengers'],order=(3,0,5),seasonal_order=(0,1,0,12))
model_SARIMA_fit=model_SARIMA.fit()
model_SARIMA_fit.summary()
# Out:
# C:\Users\dhana\anaconda3\envs\projects\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\dhana\anaconda3\envs\projects\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\dhana\anaconda3\envs\projects\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...
# Dep. Variable:             Thousands of Passengers   No. Observations:                   84
# Model:             SARIMAX(3, 0, 5)x(0, 1, [], 12)   Log Likelihood                -265.240
# ...

# %%
##prediction
pred_start_date=test_data.index[0]
pred_end_date=test_data.index[-1]
print(pred_start_date)
print(pred_end_date)
# Out:
# 1956-01-01 00:00:00
# 1960-12-01 00:00:00

# %%
pred_Sarima=model_SARIMA_fit.predict(start=datetime(1956,6,6),end=datetime(1960,12,1))
residuals=test_data['Thousands of Passengers']-pred_Sarima

# %%
model_SARIMA_fit.resid.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
model_SARIMA_fit.resid.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
test_data['Predicted_SARIMA']=pred_Sarima
# Out:
# C:\Users\dhana\AppData\Local\Temp\ipykernel_15840\1367177785.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['Predicted_SARIMA']=pred_Sarima

# %%
test_data[['Thousands of Passengers','Predicted_SARIMA','Predicted_ARIMA']].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
from fbprophet import Prophet
import pandas as pd

# %%
df = pd.read_csv('./airline.csv')
df
# Out:
#        Month  Thousands of Passengers
# 0    1949-01                      112
# 1    1949-02                      118
# 2    1949-03                      132
# 3    1949-04                      129
# 4    1949-05                      121
# ..       ...                      ...
# 139  1960-08                      606
# 140  1960-09                      508
# 141  1960-10                      461
# 142  1960-11                      390
# 143  1960-12                      432
#
# [144 rows x 2 columns]

# %%
df.columns = ['ds','y']
df.head()
# Out:
#         ds    y
# 0  1949-01  112
# 1  1949-02  118
# 2  1949-03  132
# 3  1949-04  129
# 4  1949-05  121

# %%
df['ds'] = pd.to_datetime(df['ds'])

# %%
# Initialize the Model
model=Prophet()
model.fit(df)
model.component_modes
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\dhana\anaconda3\envs\projects\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# {'additive': ['yearly',
#   'additive_terms',
#   'extra_regressors_additive',
#   'holidays'],
#  'multiplicative': ['multiplicative_terms', 'extra_regressors_multiplicative']}

# %%
### Create future dates of 365 days
future_dates=model.make_future_dataframe(periods=365)

# %%
prediction=model.predict(future_dates)
# Out:
# C:\Users\dhana\anaconda3\envs\projects\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Users\dhana\anaconda3\envs\projects\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
prediction.head()
# Out:
#           ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 1949-01-01  106.320611   56.349979  114.975245   106.320611   106.320611
# 1 1949-02-01  108.500995   48.574875  105.137824   108.500995   108.500995
# 2 1949-03-01  110.470374   79.288958  139.723174   110.470374   110.470374
# 3 1949-04-01  112.650758   79.358318  136.351713   112.650758   112.650758
# 4 1949-05-01  114.760808   83.273536  139.163729   114.760808   114.760808
#
#    additive_terms  additive_terms_lower  additive_terms_upper     yearly  \
# 0      -21.941934            -21.941934            -21.941934 -21.941934
# 1      -30.714169            -30.714169            -30.714169 -30.714169
# 2       -0.475833             -0.475833             -0.475833  -0.475833
# 3       -5.203855             -5.203855             -5.203855  -5.203855
# 4       -3.825854             -3.825854             -3.825854  -3.825854
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# ...

# %%
### plot the predicted projection
model.plot(prediction)

# %%
#### Visualize Each Components[Trends,yearly]
model.plot_components(prediction)
# Out:
# C:\Users\dhana\anaconda3\envs\projects\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
'''
Time Series Analysis

1960-1962
Cross Validation
1960-61---Train dataset
1961-62--Test dataset
1962-63---Validation
'''
# Out:
# '\nTime Series Analysis\n\n1960-1962\nCross Validation\n1960-61---Train dataset\n1961-62--Test dataset\n1962-63---Validation\n'

# %%
from fbprophet.diagnostics import cross_validation
df_cv = cross_validation(model, initial='730 days', period='180 days', horizon = '365 days')
df_cv.head()
# Out:
# INFO:fbprophet:Making 19 forecasts with cutoffs between 1951-01-18 00:00:00 and 1959-12-02 00:00:00
#   0%|          | 0/19 [00:00<?, ?it/s]
# C:\Users\dhana\anaconda3\envs\projects\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# INFO:fbprophet:n_changepoints greater than number of observations. Using 19.
# C:\Users\dhana\anaconda3\envs\projects\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Users\dhana\anaconda3\envs\projects\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
from fbprophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#   horizon          mse       rmse        mae      mape     mdape  coverage
# 0 40 days  1085.982413  32.954247  25.858707  0.078429  0.073811  0.227273
# 1 42 days  1013.087718  31.829039  25.298741  0.077251  0.073811  0.181818
# 2 46 days   910.373154  30.172391  24.801127  0.079580  0.084098  0.136364
# 3 47 days  1044.626120  32.320676  26.980818  0.082844  0.085696  0.136364
# 4 48 days  1033.404419  32.146608  26.391799  0.080742  0.085696  0.181818

# %%
df_p.head()
# Out:
#   horizon          mse       rmse        mae      mape     mdape  coverage
# 0 40 days  1085.982413  32.954247  25.858707  0.078429  0.073811  0.227273
# 1 42 days  1013.087718  31.829039  25.298741  0.077251  0.073811  0.181818
# 2 46 days   910.373154  30.172391  24.801127  0.079580  0.084098  0.136364
# 3 47 days  1044.626120  32.320676  26.980818  0.082844  0.085696  0.136364
# 4 48 days  1033.404419  32.146608  26.391799  0.080742  0.085696  0.181818

# %%
from fbprophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='rmse')
